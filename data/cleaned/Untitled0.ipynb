# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv", encoding='latin1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (462115, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462115 entries, 0 to 462114
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    462115 non-null  object
#  1   StockCode    462115 non-null  object
#  2   Description  460737 non-null  object
#  3   Quantity     462115 non-null  int64
#  4   InvoiceDate  462115 non-null  object
#  5   UnitPrice    462115 non-null  float64
#  6   CustomerID   347829 non-null  float64
#  7   Country      462115 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.2+ MB

# %%
df.describe()
# Out:
#            Quantity      UnitPrice     CustomerID
# count  462115.00000  462115.000000  347829.000000
# mean        9.75856       4.670336   15284.359323
# std       163.93112      99.251335    1712.073920
# min    -74215.00000  -11062.060000   12346.000000
# 25%         1.00000       1.250000   13924.000000
# 50%         3.00000       2.080000   15159.000000
# 75%        11.00000       4.130000   16788.000000
# max     74215.00000   38970.000000   18287.000000

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1378
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     114286
# Country             0
# dtype: int64

# %%
df.nunique()
# Out:
# InvoiceNo      22734
# StockCode       4037
# Description     4161
# Quantity         663
# InvoiceDate    20497
# UnitPrice       1536
# CustomerID      4150
# Country           39
# dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA', 'United Kin'], dtype=object)

# %%
df['Country'].nunique()
# Out:
# 39

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          421171
# Germany                   8357
# France                    7323
# EIRE                      7067
# Spain                     2310
# Netherlands               2194
# Switzerland               1920
# Belgium                   1847
# Portugal                  1304
# Australia                 1224
# Norway                     861
# Channel Islands            741
# Finland                    620
# Italy                      605
# Cyprus                     518
# Sweden                     433
# Unspecified                393
# Poland                     338
# Austria                    324
# Japan                      318
# Israel                     297
# Denmark                    295
# Hong Kong                  286
# USA                        248
# Singapore                  229
# Iceland                    171
# Canada                     151
# Greece                     110
# Malta                      104
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              27
# Bahrain                     19
# Saudi Arabia                10
# United Kin                   1
# Name: count, dtype: int64

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# United Kingdom    421171
# Germany             8357
# France              7323
# EIRE                7067
# Spain               2310
# Netherlands         2194
# Switzerland         1920
# Belgium             1847
# Portugal            1304
# Australia           1224
# Name: count, dtype: int64

# %%
df['Country'].head(10)
# Out:
# 0    United Kingdom
# 1    United Kingdom
# 2    United Kingdom
# 3    United Kingdom
# 4    United Kingdom
# 5    United Kingdom
# 6    United Kingdom
# 7    United Kingdom
# 8    United Kingdom
# 9    United Kingdom
# Name: Country, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(4079)

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df.fillna(0)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 462110    575961     23581               JUMBO BAG PAISLEY PARK         1
# 462111    575961     23103         JINGLE BELL HEART DECORATION         1
# 462112    575961     22993         SET OF 4 PANTRY JELLY MOULDS         2
# 462113    575961     23198       PANTRY MAGNETIC  SHOPPING LIST         6
# 462114    575961     22720    SET OF 3 CAKE TINS PANTRY DESIGN          2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0         12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1         12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2         12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3         12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4         12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 462110  11/13/2011 12:29       2.08     16794.0  United Kingdom
# 462111  11/13/2011 12:29       1.65     16794.0  United Kingdom
# 462112  11/13/2011 12:29       1.25     16794.0  United Kingdom
# 462113  11/13/2011 12:29       1.45     16794.0  United Kingdom
# 462114  11/13/2011 12:29       4.95     16794.0      United Kin
#
# [343791 rows x 8 columns]

# %%
df[df['Quantity'] > 10]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 9         536367     84879      ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728          ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727          ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726         ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724    PANDA AND BUNNIES STICKER SHEET        12
# ...          ...       ...                                ...       ...
# 462032    575959     17021             NAMASTE SWAGAT INCENSE        42
# 462033    575959     21326   AGED GLASS SILVER T-LIGHT HOLDER        24
# 462046    575959     71038  WHITE HANGING BEADS CANDLE HOLDER        16
# 462047    575959     21620    SET OF 4 ROSE BOTANICAL CANDLES        12
# 462053    575959    35095A     BLUE VICTORIAN FABRIC OVAL BOX        12
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 9         12/1/2010 8:34       1.69     13047.0  United Kingdom
# 26        12/1/2010 8:45       3.75     12583.0          France
# 27        12/1/2010 8:45       3.75     12583.0          France
# 28        12/1/2010 8:45       3.75     12583.0          France
# 29        12/1/2010 8:45       0.85     12583.0          France
# ...                  ...        ...         ...             ...
# 462032  11/13/2011 12:27       0.30     14547.0  United Kingdom
# 462033  11/13/2011 12:27       0.65     14547.0  United Kingdom
# 462046  11/13/2011 12:27       5.45     14547.0  United Kingdom
# 462047  11/13/2011 12:27       1.25     14547.0  United Kingdom
# 462053  11/13/2011 12:27       0.42     14547.0  United Kingdom
#
# [110341 rows x 8 columns]

# %%
df[(df['Quantity'] > 10) & (df['UnitPrice'] > 5)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 65        536374     21258           VICTORIAN SEWING BOX LARGE        32
# 150       536382     22926       IVORY GIANT GARDEN THERMOMETER        12
# 880       536477     22423             REGENCY CAKESTAND 3 TIER        16
# 1218      536531    15056N            EDWARDIAN PARASOL NATURAL        12
# 1219      536531   15056BL              EDWARDIAN PARASOL BLACK        12
# ...          ...       ...                                  ...       ...
# 459261    575871     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 460585    575919     22844     VINTAGE CREAM DOG FOOD CONTAINER        12
# 460595    575919     82483   WOOD 2 DRAWER CABINET WHITE FINISH        16
# 460600    575919     22171     3 HOOK PHOTO SHELF ANTIQUE WHITE        12
# 462046    575959     71038    WHITE HANGING BEADS CANDLE HOLDER        16
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 65        12/1/2010 9:09      10.95     15100.0  United Kingdom
# 150       12/1/2010 9:45       5.95     16098.0  United Kingdom
# 880      12/1/2010 12:27      10.95     16210.0  United Kingdom
# 1218     12/1/2010 13:23       5.95     15485.0  United Kingdom
# 1219     12/1/2010 13:23       5.95     15485.0  United Kingdom
# ...                  ...        ...         ...             ...
# 459261  11/11/2011 12:52       6.95     14911.0            EIRE
# 460585  11/11/2011 17:00       7.65     15311.0  United Kingdom
# 460595  11/11/2011 17:00       5.95     15311.0  United Kingdom
# 460600  11/11/2011 17:00       7.65     15311.0  United Kingdom
# 462046  11/13/2011 12:27       5.45     14547.0  United Kingdom
#
# [2529 rows x 8 columns]

# %%
df.sort_values(by='Quantity')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 160145   C550456     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114
# 160144   C550456     21175          GIN + TONIC DIET METAL SIGN     -2000
# 160143   C550456    85123A   WHITE HANGING HEART T-LIGHT HOLDER     -1930
# ...          ...       ...                                  ...       ...
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 61624    1/18/2011 10:17       1.04     12346.0  United Kingdom
# 4287     12/2/2010 14:23       0.03     15838.0  United Kingdom
# 160145   4/18/2011 13:08       2.10     15749.0  United Kingdom
# 160144   4/18/2011 13:08       1.85     15749.0  United Kingdom
# 160143   4/18/2011 13:08       2.55     15749.0  United Kingdom
# ...                  ...        ...         ...             ...
# 270885   7/19/2011 17:04       0.06     14609.0  United Kingdom
# 97432    2/22/2011 10:43       0.82     18087.0  United Kingdom
# 206121   5/27/2011 10:52       0.72     13135.0  United Kingdom
# 421632  10/27/2011 12:26       0.21     12901.0  United Kingdom
# 61619    1/18/2011 10:01       1.04     12346.0  United Kingdom
#
# [343791 rows x 8 columns]

# %%
df.sort_values(by='Quantity', ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# ...          ...       ...                                  ...       ...
# 160143   C550456    85123A   WHITE HANGING HEART T-LIGHT HOLDER     -1930
# 160144   C550456     21175          GIN + TONIC DIET METAL SIGN     -2000
# 160145   C550456     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 61619    1/18/2011 10:01       1.04     12346.0  United Kingdom
# 421632  10/27/2011 12:26       0.21     12901.0  United Kingdom
# 206121   5/27/2011 10:52       0.72     13135.0  United Kingdom
# 97432    2/22/2011 10:43       0.82     18087.0  United Kingdom
# 270885   7/19/2011 17:04       0.06     14609.0  United Kingdom
# ...                  ...        ...         ...             ...
# 160143   4/18/2011 13:08       2.55     15749.0  United Kingdom
# 160144   4/18/2011 13:08       1.85     15749.0  United Kingdom
# 160145   4/18/2011 13:08       2.10     15749.0  United Kingdom
# 4287     12/2/2010 14:23       0.03     15838.0  United Kingdom
# 61624    1/18/2011 10:17       1.04     12346.0  United Kingdom
#
# [343791 rows x 8 columns]

# %%
df.groupby('Country')['Quantity'].sum()
# Out:
# Country
# Australia                 80289
# Austria                    3962
# Bahrain                     260
# Belgium                   20883
# Brazil                      356
# Canada                     2763
# Channel Islands            9338
# Cyprus                     6009
# Czech Republic              632
# Denmark                    6478
# EIRE                     121360
# European Community          497
# Finland                    9557
# France                    96599
# Germany                  103836
# Greece                     1320
# Iceland                    2266
# Israel                     3987
# Italy                      5986
# Japan                     21017
# Lebanon                     386
# Lithuania                   652
# Malta                       776
# Netherlands              184026
# Norway                    13793
# Poland                     3661
# Portugal                  13713
# RSA                         352
# Saudi Arabia                 75
# Singapore                  5234
# Spain                     24213
# Sweden                    34390
# Switzerland               28775
# USA                         626
# United Arab Emirates        982
# United Kin                    2
# United Kingdom          3483194
# Unspecified                1785
# Name: Quantity, dtype: int64

# %%
df.groupby('Country')['UnitPrice'].mean()
# Out:
# Country
# Australia                 3.250531
# Austria                   4.243673
# Bahrain                   4.644118
# Belgium                   3.641944
# Brazil                    4.456250
# Canada                    6.030331
# Channel Islands           4.894068
# Cyprus                    6.976518
# Czech Republic            3.007778
# Denmark                   3.628780
# EIRE                      5.299335
# European Community        4.820492
# Finland                   5.148774
# France                    5.328898
# Germany                   3.983372
# Greece                    4.999364
# Iceland                   2.734912
# Israel                    3.670648
# Italy                     4.372347
# Japan                     2.188522
# Lebanon                   5.387556
# Lithuania                 2.841143
# Malta                     4.319038
# Netherlands               2.724143
# Norway                    6.674588
# Poland                    4.183669
# Portugal                  9.632528
# RSA                       4.277586
# Saudi Arabia              2.411000
# Singapore               109.645808
# Spain                     5.164134
# Sweden                    3.757546
# Switzerland               3.514167
# USA                       2.317621
# United Arab Emirates      3.380735
# United Kin                4.950000
# United Kingdom            3.336848
# Unspecified               3.219710
# Name: UnitPrice, dtype: float64

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom    15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom    22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34

# %%
df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     49277
# JUMBO BAG RED RETROSPOT               41304
# PACK OF 72 RETROSPOT CAKE CASES       31982
# ASSORTED COLOUR BIRD ORNAMENT         31302
# WHITE HANGING HEART T-LIGHT HOLDER    30608
# MINI PAINT SET VINTAGE                24436
# PACK OF 60 PINK PAISLEY CAKE CASES    22874
# PACK OF 12 LONDON TISSUES             22852
# BROCADE RING PURSE                    21722
# ASSORTED COLOURS SILK FAN             20664
# Name: Quantity, dtype: int64

# %%
df.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              121484.05
# WHITE HANGING HEART T-LIGHT HOLDER     84199.56
# JUMBO BAG RED RETROSPOT                76056.05
# PARTY BUNTING                          64284.92
# POSTAGE                                57234.80
# ASSORTED COLOUR BIRD ORNAMENT          50064.54
# PICNIC BASKET WICKER 60 PIECES         39619.50
# CHILLI LIGHTS                          36923.62
# JUMBO BAG PINK POLKADOT                34138.65
# SPOTTY BUNTING                         31634.24
# Name: Revenue, dtype: float64

# %%
df.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          5896598.144
# Netherlands              261387.540
# EIRE                     222532.940
# Germany                  193859.320
# France                   170554.350
# Australia                131367.970
# Switzerland               54122.690
# Spain                     48439.610
# Belgium                   36171.250
# Sweden                    34847.220
# Japan                     26997.470
# Norway                    26581.050
# Portugal                  24320.370
# Channel Islands           19690.210
# Finland                   19387.100
# Denmark                   15899.670
# Italy                     12652.230
# Cyprus                    12510.350
# Singapore                  9120.390
# Austria                    8141.340
# Poland                     7232.500
# Israel                     6988.400
# Iceland                    4085.180
# Greece                     4029.530
# Canada                     3666.380
# Unspecified                2660.770
# Malta                      1953.660
# United Arab Emirates       1902.280
# Lebanon                    1693.880
# Lithuania                  1661.060
# European Community         1291.750
# Brazil                     1143.600
# USA                        1115.640
# RSA                        1002.310
# Czech Republic              769.230
# Bahrain                     548.400
# Saudi Arabia                131.170
# United Kin                    9.900
# Name: Revenue, dtype: float64

# %%
df.groupby('CustomerID')['Revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# CustomerID
# 14646.0    256695.62
# 18102.0    244666.87
# 17450.0    166992.14
# 12415.0    118370.05
# 14911.0    110938.09
# 14156.0    107266.39
# 17511.0     76814.24
# 16684.0     59297.30
# 15311.0     55799.09
# 13694.0     54903.16
# Name: Revenue, dtype: float64

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 343791 entries, 0 to 462114
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    343791 non-null  object
#  1   StockCode    343791 non-null  object
#  2   Description  343791 non-null  object
#  3   Quantity     343791 non-null  int64
#  4   InvoiceDate  343791 non-null  datetime64[ns]
#  5   UnitPrice    343791 non-null  float64
#  6   CustomerID   343791 non-null  float64
#  7   Country      343791 non-null  object
#  8   Revenue      343791 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 26.2+ MB

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month

# %%
df.groupby('Month')['Revenue'].sum()
# Out:
# Month
# 1     473731.900
# 2     435534.070
# 3     578576.210
# 4     425222.671
# 5     647011.670
# 6     606862.520
# 7     573112.321
# 8     615078.090
# 9     929356.232
# 10    973306.380
# 11    456901.930
# 12    552372.860
# Name: Revenue, dtype: float64

# %%
df['Day'] = df['InvoiceDate'].dt.day
df.groupby('Day')['Revenue'].sum()
# Out:
# Day
# 1     236852.300
# 2     207525.230
# 3     263034.110
# 4     290181.320
# 5     289847.580
# 6     276696.900
# 7     299260.930
# 8     236448.240
# 9     266810.110
# 10    272150.650
# 11    324300.420
# 12    214517.260
# 13    227741.150
# 14    271572.170
# 15    250870.881
# 16    226321.650
# 17    265025.870
# 18    216873.520
# 19    239266.540
# 20    321852.460
# 21    270697.270
# 22    195680.090
# 23    169997.090
# 24    218414.870
# 25    195642.241
# 26    180104.872
# 27    192417.960
# 28    239617.650
# 29    114624.610
# 30    158868.590
# 31    133852.320
# Name: Revenue, dtype: float64

# %%
df[df['InvoiceNo'].astype(str).str.startswith('C')]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 141      C536379         D                           Discount        -1
# 154      C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                                ...       ...
# 461418   C575940     21820  GLITTER HEART GARLAND WITH BELLS        -18
# 461419   C575940     21811            HANGING HEART WITH BELL       -48
# 461420   C575940     21621         VINTAGE UNION JACK BUNTING        -6
# 461859   C575953     21813       GARLAND WITH STARS AND BELLS        -1
# 461860   C575953     21812      GARLAND WITH HEARTS AND BELLS        -2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom   -27.50
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom    -4.65
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom   -19.80
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# ...                    ...        ...         ...             ...      ...
# 461418 2011-11-13 11:38:00       3.75     17838.0  United Kingdom   -67.50
# 461419 2011-11-13 11:38:00       0.39     17838.0  United Kingdom   -18.72
# 461420 2011-11-13 11:38:00       8.50     17838.0  United Kingdom   -51.00
# 461859 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -4.95
# 461860 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -9.90
#
#         Year  Month  Day
# 141     2010     12    1
# 154     2010     12    1
# 235     2010     12    1
# 236     2010     12    1
# 237     2010     12    1
# ...      ...    ...  ...
# 461418  2011     11   13
# 461419  2011     11   13
# 461420  2011     11   13
# 461859  2011     11   13
# 461860  2011     11   13
#
# [7919 rows x 12 columns]

# %%
df['InvoiceNo'].astype(str).str.startswith('C').sum()
# Out:
# np.int64(7919)

# %%
df['CustomerID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['InvoiceNo'].astype(str).str.startswith('C')]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 141      C536379         D                           Discount        -1
# 154      C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                                ...       ...
# 461418   C575940     21820  GLITTER HEART GARLAND WITH BELLS        -18
# 461419   C575940     21811            HANGING HEART WITH BELL       -48
# 461420   C575940     21621         VINTAGE UNION JACK BUNTING        -6
# 461859   C575953     21813       GARLAND WITH STARS AND BELLS        -1
# 461860   C575953     21812      GARLAND WITH HEARTS AND BELLS        -2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom   -27.50
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom    -4.65
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom   -19.80
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# ...                    ...        ...         ...             ...      ...
# 461418 2011-11-13 11:38:00       3.75     17838.0  United Kingdom   -67.50
# 461419 2011-11-13 11:38:00       0.39     17838.0  United Kingdom   -18.72
# 461420 2011-11-13 11:38:00       8.50     17838.0  United Kingdom   -51.00
# 461859 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -4.95
# 461860 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -9.90
#
#         Year  Month  Day
# 141     2010     12    1
# 154     2010     12    1
# 235     2010     12    1
# 236     2010     12    1
# 237     2010     12    1
# ...      ...    ...  ...
# 461418  2011     11   13
# 461419  2011     11   13
# 461420  2011     11   13
# 461859  2011     11   13
# 461860  2011     11   13
#
# [7919 rows x 12 columns]

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 141      C536379         D                           Discount        -1
# 154      C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                                ...       ...
# 461418   C575940     21820  GLITTER HEART GARLAND WITH BELLS        -18
# 461419   C575940     21811            HANGING HEART WITH BELL       -48
# 461420   C575940     21621         VINTAGE UNION JACK BUNTING        -6
# 461859   C575953     21813       GARLAND WITH STARS AND BELLS        -1
# 461860   C575953     21812      GARLAND WITH HEARTS AND BELLS        -2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom   -27.50
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom    -4.65
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom   -19.80
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom    -6.96
# ...                    ...        ...         ...             ...      ...
# 461418 2011-11-13 11:38:00       3.75     17838.0  United Kingdom   -67.50
# 461419 2011-11-13 11:38:00       0.39     17838.0  United Kingdom   -18.72
# 461420 2011-11-13 11:38:00       8.50     17838.0  United Kingdom   -51.00
# 461859 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -4.95
# 461860 2011-11-13 11:56:00       4.95     16015.0  United Kingdom    -9.90
#
#         Year  Month  Day
# 141     2010     12    1
# 154     2010     12    1
# 235     2010     12    1
# 236     2010     12    1
# 237     2010     12    1
# ...      ...    ...  ...
# 461418  2011     11   13
# 461419  2011     11   13
# 461420  2011     11   13
# 461859  2011     11   13
# 461860  2011     11   13
#
# [7919 rows x 12 columns]

# %%
df = df[df['Quantity'] > 0]

# %%
df[df['UnitPrice'] <= 0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 187613    553000     47566                        PARTY BUNTING         4
# 198383    554037     22619            SET OF 6 SOLDIER SKITTLES        80
# 279324    561284     22167           OVAL WALL MIRROR DIAMANTE          1
# 282912    561669     22960             JAM MAKING SET WITH JARS        11
# 285657    561916         M                               Manual         1
# 298054    562973     23157           SET OF 6 NATIVITY MAGNETS        240
# 314745    564651     23270     SET OF 2 CERAMIC PAINTED HEARTS         96
# 314746    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192
# 314747    564651     22955             36 FOIL STAR CAKE CASES        144
# 314748    564651     21786                   POLKADOT RAIN HAT        144
# 358655    568158      PADS           PADS TO MATCH ALL CUSHIONS         1
# 361825    568384         M                               Manual         1
# 379913    569716     22778                   GLASS CLOCHE SMALL         2
# 395529    571035         M                               Manual         1
# 420404    572893     21208          PASTEL COLOUR HONEYCOMB FAN         5
# 436428    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS       216
# 436597    574175     22065       CHRISTMAS PUDDING TRINKET POT         12
# 436961    574252         M                               Manual         1
# 439361    574469     22385            JUMBO BAG SPACEBOY DESIGN        12
# 446125    574879     22625                   RED KITCHEN SCALES         2
# 446793    574920     22899         CHILDREN'S APRON DOLLY GIRL          1
# 446794    574920     23480       MINI LIGHTS WOODLAND MUSHROOMS         1
# 454463    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 454464    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 9302   2010-12-05 14:02:00        0.0     12647.0         Germany      0.0
# 33576  2010-12-16 14:36:00        0.0     16560.0  United Kingdom      0.0
# 40089  2010-12-21 13:45:00        0.0     14911.0            EIRE      0.0
# 47068  2011-01-06 16:41:00        0.0     13081.0  United Kingdom      0.0
# 47070  2011-01-06 16:41:00        0.0     13081.0  United Kingdom      0.0
# 56674  2011-01-13 15:10:00        0.0     15107.0  United Kingdom      0.0
# 86789  2011-02-10 13:08:00        0.0     17560.0  United Kingdom      0.0
# 130188 2011-03-23 10:25:00        0.0     13239.0  United Kingdom      0.0
# 139453 2011-03-30 12:45:00        0.0     13113.0  United Kingdom      0.0
# 145208 2011-04-04 14:42:00        0.0     14410.0  United Kingdom      0.0
# 157042 2011-04-14 18:57:00        0.0     12457.0     Switzerland      0.0
# 187613 2011-05-12 15:21:00        0.0     17667.0  United Kingdom      0.0
# 198383 2011-05-20 14:13:00        0.0     12415.0       Australia      0.0
# 279324 2011-07-26 12:24:00        0.0     16818.0  United Kingdom      0.0
# 282912 2011-07-28 17:09:00        0.0     12507.0           Spain      0.0
# 285657 2011-08-01 11:44:00        0.0     15581.0  United Kingdom      0.0
# 298054 2011-08-11 11:42:00        0.0     14911.0            EIRE      0.0
# 314745 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314746 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314747 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 314748 2011-08-26 14:19:00        0.0     14646.0     Netherlands      0.0
# 358655 2011-09-25 12:22:00        0.0     16133.0  United Kingdom      0.0
# 361825 2011-09-27 09:46:00        0.0     12748.0  United Kingdom      0.0
# 379913 2011-10-06 08:17:00        0.0     15804.0  United Kingdom      0.0
# 395529 2011-10-13 12:50:00        0.0     12446.0             RSA      0.0
# 420404 2011-10-26 14:36:00        0.0     18059.0  United Kingdom      0.0
# 436428 2011-11-03 11:26:00        0.0     12415.0       Australia      0.0
# 436597 2011-11-03 11:47:00        0.0     14110.0  United Kingdom      0.0
# 436961 2011-11-03 13:24:00        0.0     12437.0          France      0.0
# 439361 2011-11-04 11:55:00        0.0     12431.0       Australia      0.0
# 446125 2011-11-07 13:22:00        0.0     13014.0  United Kingdom      0.0
# 446793 2011-11-07 16:34:00        0.0     13985.0  United Kingdom      0.0
# 446794 2011-11-07 16:34:00        0.0     13985.0  United Kingdom      0.0
# 454463 2011-11-10 11:49:00        0.0     13081.0  United Kingdom      0.0
# 454464 2011-11-10 11:49:00        0.0     13081.0  United Kingdom      0.0
#
#         Year  Month  Day
# 9302    2010     12    5
# 33576   2010     12   16
# 40089   2010     12   21
# 47068   2011      1    6
# 47070   2011      1    6
# 56674   2011      1   13
# 86789   2011      2   10
# 130188  2011      3   23
# 139453  2011      3   30
# 145208  2011      4    4
# 157042  2011      4   14
# 187613  2011      5   12
# 198383  2011      5   20
# 279324  2011      7   26
# 282912  2011      7   28
# 285657  2011      8    1
# 298054  2011      8   11
# 314745  2011      8   26
# 314746  2011      8   26
# 314747  2011      8   26
# 314748  2011      8   26
# 358655  2011      9   25
# 361825  2011      9   27
# 379913  2011     10    6
# 395529  2011     10   13
# 420404  2011     10   26
# 436428  2011     11    3
# 436597  2011     11    3
# 436961  2011     11    3
# 439361  2011     11    4
# 446125  2011     11    7
# 446793  2011     11    7
# 446794  2011     11    7
# 454463  2011     11   10
# 454464  2011     11   10

# %%
df.shape
# Out:
# (335872, 12)

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x, y)
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x='Country', data=df)
plt.show()

# %%
country_sales = df.groupby('Country')['Revenue'].sum().sort_values(ascending=False).head(10)

country_sales.plot(kind='bar', figsize=(10,5))
plt.show()

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar', figsize=(12,5))
plt.show()

# %%
monthly_sales = df.groupby('Month')['Revenue'].sum()

plt.plot(monthly_sales)
plt.show()

# %%
plt.hist(df['Quantity'])
plt.show()

# %%
sns.heatmap(df[['Quantity','UnitPrice','Revenue']].corr(), annot=True)
plt.show()

# %%
sns.boxplot(x=df['UnitPrice'])
plt.show()
